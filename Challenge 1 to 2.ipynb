# %%
# Good morning! Here's your coding interview problem for today.

#This problem was recently asked by Google.

#Given a list of numbers and a number k, return whether any two numbers from the list add up to k.

#For example, given [10, 15, 3, 7] and k of 17, return true since 10 + 7 is 17.


k = 17
nums =[8,0,0,1,9]

def check_sum(nums, k):
    #loop through the list
    
    for i in range(len(nums)):
        
        #loop though the shrunken list
        
        for j in range(i+1, len(nums)):
            
            #check if values add together
            
            if nums[i] + nums[j] == k:
                
                return True
            
    return False

check_sum(nums,k)

#r = compute(nums,k)

#if not r:
    #print('No Match!')
#else:
   # print(f'there was a match of the k value: {k}, with the {r[0]} and {r[1]} in the list')

# %%
#Given an array of integers, return a new array such that each element at index i of the new array is the product of all 
#the numbers in the original array except the one at i.

#For example, if our input was [1, 2, 3, 4, 5], the expected output would be [120, 60, 40, 30, 24]. 
#If our input was [3, 2, 1], the expected output would be [2, 3, 6].

#Follow-up: what if you can't use division?


#for an array

def compute(nums):
    
    #import numpy
    
    import numpy as np
    
    #empty array
    new_list =[]
    
    #loop the array
    
    for i in range(len(nums)):
        
        #set up the remplacemnt value to enter into the new_list
        
        x = 1
        
        #get index and value of the array
        
        for index, value in enumerate(nums):
            
            #make sure index to = to 1
            
            if index != value:
                #manipulate value to enter into array
                x *= value
            else:
                x *= 1
    #append value into list
        
    new_list.append(x)
    
    #return array
    
    return np.array(new_list)
            
        
        
#for a list
def compute(nums):
    new_list =[]
    #getting the index
    for index, value in enumerate(nums):
        #change value in list to the one
        original_list = nums
        original_int = original_list[index]
        original_list[index] = 1
        
        #get product of manipualated list
        result = 1
        for x in original_list:
            result = result*x
         
        #return the list, whilst remebering to replace the index
        new_list.append(result)
        
        original_list[index] = original_int
        
    return new_list        
        
        
        
        
        

compute([1, 2, 3, 4, 5])
